# %%
#Import dependencies
import pandas as pd
import datetime as dt
import numpy as np

# %%
nba_draft = pd.read_csv("2007-2016_nba_draft_rd1-2.csv", engine='python')
nba_draft.head()
# Out:
#    Rk  Year   Lg  Rd  Pk   Tm             Player     Age  Pos Born  ...  TRB  \
# 0   1  2007  NBA   1   2  SEA       Kevin Durant  18.276  F-G   us  ...  7.1
# 1   2  2009  NBA   1   3  OKC       James Harden  19.308    G   us  ...  5.3
# 2   3  2009  NBA   1   7  GSW      Stephen Curry  21.108    G   us  ...  4.5
# 3   4  2008  NBA   1   4  SEA  Russell Westbrook  19.231    G   us  ...  7.1
# 4   5  2007  NBA   1   3  ATL         Al Horford  21.030  C-F   do  ...  8.3
#
#    AST  STL  BLK    FG%    2P%    3P%    FT%     WS  WS/48
# 0  4.1  1.1  1.1  0.493  0.532  0.381  0.883  141.7  0.217
# 1  6.3  1.6  0.5  0.443  0.508  0.364  0.858  131.9  0.226
# 2  6.6  1.7  0.2  0.476  0.515  0.435  0.905  103.1  0.206
# 3  8.3  1.7  0.3  0.436  0.468  0.304  0.801  100.5  0.161
# 4  3.3  0.8  1.2  0.520  0.544  0.361  0.753   89.8  0.158
#
# [5 rows x 26 columns]

# %%
draft_condensed = nba_draft[["Player", "Year", "Tm", "College"]]
draft_condensed.head()
# Out:
#               Player  Year   Tm        College
# 0       Kevin Durant  2007  SEA          Texas
# 1       James Harden  2009  OKC  Arizona State
# 2      Stephen Curry  2009  GSW       Davidson
# 3  Russell Westbrook  2008  SEA           UCLA
# 4         Al Horford  2007  ATL        Florida

# %%
first_year = draft_condensed.loc[draft_condensed["Year"] == 2007].copy()

# %%
first_year
# Out:
#                  Player  Year   Tm             College
# 0          Kevin Durant  2007  SEA               Texas
# 4            Al Horford  2007  ATL             Florida
# 6            Marc Gasol  2007  LAL                 NaN
# 12          Mike Conley  2007  MEM          Ohio State
# 20          Joakim Noah  2007  CHI             Florida
# 23       Thaddeus Young  2007  PHI        Georgia Tech
# 51         Jared Dudley  2007  CHA      Boston College
# 58           Jeff Green  2007  BOS          Georgetown
# 65          Carl Landry  2007  SEA              Purdue
# 70        Arron Afflalo  2007  DET                UCLA
# 77      Marco Belinelli  2007  GSW                 NaN
# 83      Wilson Chandler  2007  NYK              DePaul
# 85       Ramon Sessions  2007  MIL              Nevada
# 86       Rodney Stuckey  2007  DET  Eastern Washington
# 96       Brandan Wright  2007  CHA                 UNC
# 102      Tiago Splitter  2007  SAS                 NaN
# ...

# %%
OhSeven_stats = pd.read_csv("stats_2007.csv", engine='python')

# %%
OhSeven_stats
# Out:
#     attempted_three_point_field_goals  blocks       slug  personal_fouls  \
# 0                                  20      40  abdursh01             243
# 1                                   1       4  adamsha01              47
# 2                                  15       3   agerma01              27
# 3                                   2      73  aldrila01             186
# 4                                   1      16  allenma01              85
# 5                                 443      11  allenra02             113
# 6                                  33      12  allento01              87
# 7                                 529      10  alstora01             195
# 8                                   0       0  amundlo01               0
# 9                                   0       8  amundlo01              15
# 10                                 20       0  anderal01              33
# 11                                152       7  anderde01             115
# ...

# %%
OhSevenCondensed = OhSeven_stats[["name", "points", "assists", "defensive_rebounds", "offensive_rebounds"]]
OhSevenCondensed.head()
# Out:
#                   name  points  assists  defensive_rebounds  \
# 0  Shareef Abdur-Rahim     793      109                 276
# 1         Hassan Adams     174       13                  42
# 2         Maurice Ager      69        7                  20
# 3    LaMarcus Aldridge     565       24                 168
# 4          Malik Allen     242       16                  77
#
#    offensive_rebounds
# 0                 122
# 1                  35
# 2                   1
# 3                 144
# 4                  42

# %%
OhEight_stats = pd.read_csv("stats_2008.csv", engine='python')

# %%
OhEight_stats
# Out:
#     attempted_three_point_field_goals  blocks       slug  personal_fouls  \
# 0                                   0       0  abdursh01               9
# 1                                  48       8  afflaar01              83
# 2                                   8       1   agerma01              11
# 3                                  11       0   agerma01               6
# 4                                  34       0  ahearbl01              20
# 5                                   7      94  aldrila01             240
# 6                                   2      21  allenma01              89
# 7                                   0      10  allenma01              60
# 8                                 452      16  allenra02             147
# 9                                  57      21  allento01             168
# 10                                  0       0  allrela01               1
# 11                                  4       0  almonmo01               5
# ...

# %%
OhEightCondensed = OhEight_stats[["name", "points", "assists", "defensive_rebounds", "offensive_rebounds"]]
OhEightCondensed.head()
# Out:
#                   name  points  assists  defensive_rebounds  \
# 0  Shareef Abdur-Rahim      10        4                   4
# 1        Arron Afflalo     276       52                 101
# 2         Maurice Ager      15        4                   3
# 3         Maurice Ager      36        4                   6
# 4         Blake Ahearn      70       19                  18
#
#    offensive_rebounds
# 0                   6
# 1                  36
# 2                   1
# 3                   3
# 4                   1

# %%
pd.merge(OhSevenCondensed.reset_index(), OhEightCondensed.reset_index(), on=['name'])
# Out:
#     index_x                 name  points_x  assists_x  defensive_rebounds_x  \
# 0         0  Shareef Abdur-Rahim       793        109                   276
# 1         2         Maurice Ager        69          7                    20
# 2         2         Maurice Ager        69          7                    20
# 3         3    LaMarcus Aldridge       565         24                   168
# 4         4          Malik Allen       242         16                    77
# 5         4          Malik Allen       242         16                    77
# 6         5           Ray Allen*      1454        228                   190
# 7         6           Tony Allen       379         56                    89
# 8         7         Rafer Alston      1088        444                   253
# 9         8         Lou Amundson         0          0                     0
# 10        9         Lou Amundson        16          1                    15
# ...

# %%
OhNine_stats = pd.read_csv("stats_2009.csv", engine='python')

# %%
OhNine_stats
# Out:
#     attempted_three_point_field_goals  blocks       slug  personal_fouls  \
# 0                                   4       1  ackeral01               0
# 1                                  16       3  ackeral01               9
# 2                                   0       1  adamsha01               4
# 3                                 107      13  afflaar01             144
# 4                                   6       2   agerma01              17
# 5                                   4       0  ahearbl01               3
# 6                                   2       6  ajincal01              34
# 7                                  28      77  aldrila01             207
# 8                                  46      29  alexajo01             107
# 9                                   1      12  allenma01              89
# 10                                486      13  allenra02             157
# 11                                 27      23  allento01              98
# ...

# %%
OhNineCondensed = OhNine_stats[["name", "points", "assists", "defensive_rebounds", "offensive_rebounds"]]
OhNineCondensed.head()
# Out:
#             name  points  assists  defensive_rebounds  offensive_rebounds
# 0     Alex Acker       9        1                   2                   0
# 1     Alex Acker      63       11                  14                   8
# 2   Hassan Adams      11        1                   6                   1
# 3  Arron Afflalo     363       44                 104                  30
# 4   Maurice Ager      34        3                   7                   3

# %%
SevenEight = pd.merge(OhSevenCondensed, OhEightCondensed, on=['name'])
SevenEight
# Out:
#                    name  points_x  assists_x  defensive_rebounds_x  \
# 0   Shareef Abdur-Rahim       793        109                   276
# 1          Maurice Ager        69          7                    20
# 2          Maurice Ager        69          7                    20
# 3     LaMarcus Aldridge       565         24                   168
# 4           Malik Allen       242         16                    77
# 5           Malik Allen       242         16                    77
# 6            Ray Allen*      1454        228                   190
# 7            Tony Allen       379         56                    89
# 8          Rafer Alston      1088        444                   253
# 9          Lou Amundson         0          0                     0
# 10         Lou Amundson        16          1                    15
# 11       Derek Anderson       399        133                    84
# 12      Carmelo Anthony      1881        249                   248
# ...

# %%
SevenEightTPts = SevenEight["points_x"] + SevenEight["points_y"]
SevenEight["Total Points"] = SevenEightTPts
SevenEight.head()
# Out:
#                   name  points_x  assists_x  defensive_rebounds_x  \
# 0  Shareef Abdur-Rahim       793        109                   276
# 1         Maurice Ager        69          7                    20
# 2         Maurice Ager        69          7                    20
# 3    LaMarcus Aldridge       565         24                   168
# 4          Malik Allen       242         16                    77
#
#    offensive_rebounds_x  points_y  assists_y  defensive_rebounds_y  \
# 0                   122        10          4                     4
# 1                     1        15          4                     3
# 2                     1        36          4                     6
# 3                   144      1350        122                   358
# 4                    42       261         29                    86
#
#    offensive_rebounds_y  total points  Total Points
# 0                     6           803           803
# 1                     1            84            84
# ...

# %%
SevenEightDRbs = SevenEight["defensive_rebounds_x"] + SevenEight["defensive_rebounds_y"]
SevenEight["Total Defensive Rebounds"] = SevenEightDRbs
SevenEight.head()
# Out:
#                   name  points_x  assists_x  defensive_rebounds_x  \
# 0  Shareef Abdur-Rahim       793        109                   276
# 1         Maurice Ager        69          7                    20
# 2         Maurice Ager        69          7                    20
# 3    LaMarcus Aldridge       565         24                   168
# 4          Malik Allen       242         16                    77
#
#    offensive_rebounds_x  points_y  assists_y  defensive_rebounds_y  \
# 0                   122        10          4                     4
# 1                     1        15          4                     3
# 2                     1        36          4                     6
# 3                   144      1350        122                   358
# 4                    42       261         29                    86
#
#    offensive_rebounds_y  total points  Total Points  Total Defensive Rebounds
# 0                     6           803           803                       280
# ...

# %%
SevenEightORbs = SevenEight["offensive_rebounds_x"] + SevenEight["offensive_rebounds_y"]
SevenEight["Total Offensive Rebounds"] = SevenEightORbs
SevenEight.head()
# Out:
#                   name  points_x  assists_x  defensive_rebounds_x  \
# 0  Shareef Abdur-Rahim       793        109                   276
# 1         Maurice Ager        69          7                    20
# 2         Maurice Ager        69          7                    20
# 3    LaMarcus Aldridge       565         24                   168
# 4          Malik Allen       242         16                    77
#
#    offensive_rebounds_x  points_y  assists_y  defensive_rebounds_y  \
# 0                   122        10          4                     4
# 1                     1        15          4                     3
# 2                     1        36          4                     6
# 3                   144      1350        122                   358
# 4                    42       261         29                    86
#
#    offensive_rebounds_y  total points  Total Points  Total Defensive Rebounds  \
# 0                     6           803           803                       280
# ...

# %%
SevenEightTotalAssists = SevenEight["assists_x"] + SevenEight["assists_y"]
SevenEight["Total Asists"] = SevenEightTotalAssists
SevenEight.head()
# Out:
#                   name  points_x  assists_x  defensive_rebounds_x  \
# 0  Shareef Abdur-Rahim       793        109                   276
# 1         Maurice Ager        69          7                    20
# 2         Maurice Ager        69          7                    20
# 3    LaMarcus Aldridge       565         24                   168
# 4          Malik Allen       242         16                    77
#
#    offensive_rebounds_x  points_y  assists_y  defensive_rebounds_y  \
# 0                   122        10          4                     4
# 1                     1        15          4                     3
# 2                     1        36          4                     6
# 3                   144      1350        122                   358
# 4                    42       261         29                    86
#
#    offensive_rebounds_y  total points  Total Points  Total Defensive Rebounds  \
# 0                     6           803           803                       280
# ...

# %%
SevenEightTRebounds = SevenEight["Total Defensive Rebounds"] + SevenEight["Total Offensive Rebounds"]
SevenEight.head()
# Out:
#                   name  points_x  assists_x  defensive_rebounds_x  \
# 0  Shareef Abdur-Rahim       793        109                   276
# 1         Maurice Ager        69          7                    20
# 2         Maurice Ager        69          7                    20
# 3    LaMarcus Aldridge       565         24                   168
# 4          Malik Allen       242         16                    77
#
#    offensive_rebounds_x  points_y  assists_y  defensive_rebounds_y  \
# 0                   122        10          4                     4
# 1                     1        15          4                     3
# 2                     1        36          4                     6
# 3                   144      1350        122                   358
# 4                    42       261         29                    86
#
#    offensive_rebounds_y  total points  Total Points  Total Defensive Rebounds  \
# 0                     6           803           803                       280
# ...

# %%
OhNinestats = pd.read_csv("stats_2009.csv", engine='python')
OhNinestats
# Out:
#     attempted_three_point_field_goals  blocks       slug  personal_fouls  \
# 0                                   4       1  ackeral01               0
# 1                                  16       3  ackeral01               9
# 2                                   0       1  adamsha01               4
# 3                                 107      13  afflaar01             144
# 4                                   6       2   agerma01              17
# 5                                   4       0  ahearbl01               3
# 6                                   2       6  ajincal01              34
# 7                                  28      77  aldrila01             207
# 8                                  46      29  alexajo01             107
# 9                                   1      12  allenma01              89
# 10                                486      13  allenra02             157
# 11                                 27      23  allento01              98
# ...

# %%
SevenEightNine = pd.merge(SevenEight, OhNinestats, on=['name'])
SevenEightNine.head()
# Out:
#                 name  points_x  assists_x  defensive_rebounds_x  \
# 0       Maurice Ager        69          7                    20
# 1       Maurice Ager        69          7                    20
# 2  LaMarcus Aldridge       565         24                   168
# 3        Malik Allen       242         16                    77
# 4        Malik Allen       242         16                    77
#
#    offensive_rebounds_x  points_y  assists_y  defensive_rebounds_y  \
# 0                     1        15          4                     3
# 1                     1        36          4                     6
# 2                   144      1350        122                   358
# 3                    42       261         29                    86
# 4                    42        77         15                    44
#
#    offensive_rebounds_y  total points  ...  games_started  age  steals  \
# 0                     1            84  ...              0   24       1
# ...

# %%
SevenEightNineTpoints = SevenEight["total points"] + OhNinestats["points"]
SevenEightNine["Total baskets"] = SevenEightNineTpoints
SevenEightNine.head()
OhNinestats['points']
print(SevenEightNineTpoints.head())
print(SevenEight['total points'].head())
print(OhNinestats["points"].head())
# Out:
# 0      93.0
# 1     168.0
# 2    1926.0
# 3     866.0
# 4     353.0
# dtype: float64
# 0     803
# 1      84
# 2     105
# 3    1915
# 4     503
# Name: total points, dtype: int64
# 0      9
# 1     63
# 2     11
# 3    363
# 4     34
# Name: points, dtype: int64

# %%
SevenEightNineTpoints = SevenEightNine["total points"] + SevenEightNine["points"]
SevenEightNineTpoints.head()
# Out:
# 0     118
# 1     139
# 2    3385
# 3     659
# 4     475
# dtype: int64

# %%
SevenEightNine["Total points overall"] = SevenEightNineTpoints
SevenEightNine.head()
# Out:
#                 name  points_x  assists_x  defensive_rebounds_x  \
# 0       Maurice Ager        69          7                    20
# 1       Maurice Ager        69          7                    20
# 2  LaMarcus Aldridge       565         24                   168
# 3        Malik Allen       242         16                    77
# 4        Malik Allen       242         16                    77
#
#    offensive_rebounds_x  points_y  assists_y  defensive_rebounds_y  \
# 0                     1        15          4                     3
# 1                     1        36          4                     6
# 2                   144      1350        122                   358
# 3                    42       261         29                    86
# 4                    42        77         15                    44
#
#    offensive_rebounds_y  total points  ...  steals  \
# 0                     1            84  ...       1
# 1                     3           105  ...       1
# ...

# %%
SevenEightNineTDrebounds = SevenEightNine["defensive_rebounds_x"] + SevenEightNine["defensive_rebounds_y"] + SevenEightNine["defensive_rebounds"]
SevenEightNineTDrebounds.head()
# Out:
# 0     30
# 1     33
# 2    897
# 3    231
# 4    189
# dtype: int64

# %%
SevenEightNine["Total defensive rebounds"] = SevenEightNineTDrebounds
SevenEightNine.head()
# Out:
#                 name  points_x  assists_x  defensive_rebounds_x  \
# 0       Maurice Ager        69          7                    20
# 1       Maurice Ager        69          7                    20
# 2  LaMarcus Aldridge       565         24                   168
# 3        Malik Allen       242         16                    77
# 4        Malik Allen       242         16                    77
#
#    offensive_rebounds_x  points_y  assists_y  defensive_rebounds_y  \
# 0                     1        15          4                     3
# 1                     1        36          4                     6
# 2                   144      1350        122                   358
# 3                    42       261         29                    86
# 4                    42        77         15                    44
#
#    offensive_rebounds_y  total points  ...                         team  \
# 0                     1            84  ...         Team.NEW_JERSEY_NETS
# ...

# %%
SevenEightNineTOrebounds = SevenEightNine["offensive_rebounds_x"] + SevenEightNine["offensive_rebounds_y"] + SevenEightNine["offensive_rebounds"]
SevenEightNineTOrebounds.head()
# Out:
# 0      5
# 1      7
# 2    598
# 3    119
# 4    101
# dtype: int64

# %%
SevenEightNine["Total offensive rebounds"] = SevenEightNineTOrebounds
SevenEightNine.head()
# Out:
#                 name  points_x  assists_x  defensive_rebounds_x  \
# 0       Maurice Ager        69          7                    20
# 1       Maurice Ager        69          7                    20
# 2  LaMarcus Aldridge       565         24                   168
# 3        Malik Allen       242         16                    77
# 4        Malik Allen       242         16                    77
#
#    offensive_rebounds_x  points_y  assists_y  defensive_rebounds_y  \
# 0                     1        15          4                     3
# 1                     1        36          4                     6
# 2                   144      1350        122                   358
# 3                    42       261         29                    86
# 4                    42        77         15                    44
#
#    offensive_rebounds_y  total points  ...  points  attempted_free_throws  \
# 0                     1            84  ...      34                      8
# ...

# %%
SevenEightNineTAssists = SevenEightNine["assists_x"] + SevenEightNine["assists_y"] + SevenEightNine["assists"]
SevenEightNineTAssists.head()
# Out:
# 0     14
# 1     14
# 2    303
# 3     80
# 4     66
# dtype: int64

# %%
SevenEightNine["Total assists"] = SevenEightNineTAssists
SevenEightNine.head()
# Out:
#                 name  points_x  assists_x  defensive_rebounds_x  \
# 0       Maurice Ager        69          7                    20
# 1       Maurice Ager        69          7                    20
# 2  LaMarcus Aldridge       565         24                   168
# 3        Malik Allen       242         16                    77
# 4        Malik Allen       242         16                    77
#
#    offensive_rebounds_x  points_y  assists_y  defensive_rebounds_y  \
# 0                     1        15          4                     3
# 1                     1        36          4                     6
# 2                   144      1350        122                   358
# 3                    42       261         29                    86
# 4                    42        77         15                    44
#
#    offensive_rebounds_y  total points  ...  attempted_free_throws  \
# 0                     1            84  ...                      8
# ...
